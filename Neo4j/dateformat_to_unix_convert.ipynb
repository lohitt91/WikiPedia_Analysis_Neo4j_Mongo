# %%
import pandas as pd
import time

# %%
df1 = pd.read_csv("C:/Users/adity/Downloads/Votes.csv",sep = ',', header = 0);

# %%
df1
# Out:
#           Id  PostId  VoteTypeId         CreationDate   UserId  BountyAmount
# 0          1       1           2  2013-05-08 00:00:00      NaN           NaN
# 1          2       1           2  2013-05-08 00:00:00      NaN           NaN
# 2          3       1           2  2013-05-08 00:00:00      NaN           NaN
# 3          4       2           2  2013-05-08 00:00:00      NaN           NaN
# 4          5       4           2  2013-05-08 00:00:00      NaN           NaN
# 5          6       2           3  2013-05-08 00:00:00      NaN           NaN
# 6          7       3           2  2013-05-08 00:00:00      NaN           NaN
# 7          8       3           2  2013-05-08 00:00:00      NaN           NaN
# 8          9       5           2  2013-05-08 00:00:00      NaN           NaN
# 9         10       2           2  2013-05-08 00:00:00      NaN           NaN
# 10        11       1           2  2013-05-08 00:00:00      NaN           NaN
# ...

# %%
f=open('C:/Users/adity/Documents/Date.txt','w')
for index,row in df1.iterrows():
    date = (time.mktime(time.strptime(row[3], '%Y-%m-%d %H:%M:%S')))
    f.write(str(date)+"\n")
f.close()

# %%
date = (time.mktime(time.strptime("2014-01-01 19:06:18", '%Y-%m-%d %H:%M:%S')))
date
# Out:
# 1388563578.0

# %%
df1
# Out:
#          Id AcceptedAnswerId         CreationDate  ViewCount  OwnerUserId  \
# 0         1                2  2013-05-08 18:59:12       1798          7.0
# 1         3              NaN  2013-05-08 19:14:57         93         26.0
# 2         6              NaN  2013-05-08 19:18:47        398         44.0
# 3         7              NaN  2013-05-08 19:19:11       6093         41.0
# 4         9              NaN  2013-05-08 19:20:16        120         48.0
# 5        11                   2013-05-08 19:23:54       1844         41.0
# 6        15               30  2013-05-08 19:28:41        195         74.0
# 7        16               19  2013-05-08 19:30:11       1486         46.0
# 8        17              NaN  2013-05-08 19:31:05         77         65.0
# 9        23              NaN  2013-05-08 19:38:36        285          5.0
# 10       24               33  2013-05-08 19:39:59        544         32.0
# 11       26              NaN  2013-05-08 19:42:51       1178         87.0
# ...
